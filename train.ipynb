# %%
# !pip install git+https://github.com/csteinmetz1/iirnet.git
# Out:
# Collecting git+https://github.com/csteinmetz1/iirnet.git
#   Cloning https://github.com/csteinmetz1/iirnet.git to /private/var/folders/hr/gnm35wpn3v9gt96sywtsl34h0000gn/T/pip-req-build-6c6kthft
#   Running command git clone -q https://github.com/csteinmetz1/iirnet.git /private/var/folders/hr/gnm35wpn3v9gt96sywtsl34h0000gn/T/pip-req-build-6c6kthft
#   Resolved https://github.com/csteinmetz1/iirnet.git to commit 946a37e6a7dcc772106182c6bc9260839f447cc2
# Requirement already satisfied: torch in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (1.9.1)
# Requirement already satisfied: torchaudio in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (0.9.1)
# Requirement already satisfied: torchvision in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (0.10.1)
# Requirement already satisfied: pytorch_lightning in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (1.4.9)
# Requirement already satisfied: scipy in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (1.7.1)
# Requirement already satisfied: matplotlib in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (3.4.3)
# Requirement already satisfied: wget in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from iirnet==0.0.1) (3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from matplotlib->iirnet==0.0.1) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from matplotlib->iirnet==0.0.1) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from matplotlib->iirnet==0.0.1) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from matplotlib->iirnet==0.0.1) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from matplotlib->iirnet==0.0.1) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from matplotlib->iirnet==0.0.1) (1.3.2)
# Requirement already satisfied: six in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->iirnet==0.0.1) (1.16.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (4.62.3)
# Requirement already satisfied: tensorboard>=2.2.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (2.6.0)
# Requirement already satisfied: future>=0.17.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (0.18.2)
# Requirement already satisfied: torchmetrics>=0.4.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (0.5.1)
# Requirement already satisfied: typing-extensions in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (3.10.0.2)
# Requirement already satisfied: packaging>=17.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (21.0)
# Requirement already satisfied: PyYAML>=5.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (5.4.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (2021.10.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pytorch_lightning->iirnet==0.0.1) (0.3.1)
# Requirement already satisfied: requests in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (2.26.0)
# Requirement already satisfied: aiohttp in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (3.7.4.post0)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (1.41.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (2.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (57.4.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (0.14.1)
# Requirement already satisfied: protobuf>=3.6.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (3.18.0)
# Requirement already satisfied: wheel>=0.26 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (0.37.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (1.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning->iirnet==0.0.1) (3.1.1)
# Requirement already satisfied: chardet<5.0,>=2.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (4.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (21.2.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/cjstein/Code/test/IIRNet/env/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning->iirnet==0.0.1) (3.0.1)

# %%
import os
import torch
import numpy as np
from argparse import ArgumentParser
import pytorch_lightning as pl

from iirnet.data import IIRFilterDataset
from iirnet.base import IIRNet
from iirnet.mlp import MLPModel
from iirnet.lstm import LSTMModel
from iirnet.callbacks import LogZPKCallback, LogTransferFnPlots

# %%
torch.backends.cudnn.benchmark = True
# torch.autograd.set_detect_anomaly(True)


def wif(id):  # worker init function
    np.random.seed((id + torch.initial_seed()) % np.iinfo(np.int32).max)


if __name__ == "__main__":
    parser = ArgumentParser()

    parser.add_argument("--shuffle", action="store_true")
    parser.add_argument("--precompute", action="store_true")
    parser.add_argument("--filter_method", type=str, default="char_poly")
    parser.add_argument("--max_train_order", type=int, default=100)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--num_workers", type=int, default=0)
    parser.add_argument("--model_name", type=str, default="mlp", help="mlp or lstm")
    parser.add_argument("--num_train_examples", type=int, default=100000)
    parser.add_argument("--num_val_examples", type=int, default=1000)
    parser.add_argument("--seed", type=int, default=14)

    temp_args, _ = parser.parse_known_args()

    # let the model add what it wants
    if temp_args.model_name == "mlp":
        parser = MLPModel.add_model_specific_args(parser)
    elif temp_args.model_name == "lstm":
        parser = LSTMModel.add_model_specific_args(parser)

    parser = pl.Trainer.add_argparse_args(
        parser
    )  # add all the available trainer options to argparse
    args = parser.parse_args()  # parse them args

    # set the log/checkpoint directory
    args.default_root_dir = os.path.join(
        "logs",
        f"{args.experiment_name}",
        f"epochs={args.max_epochs}_filter-method={args.filter_method}_filter-order={args.model_order}_hidden-dim={args.hidden_dim}",
    )
    checkpoint_callback = pl.callbacks.ModelCheckpoint(
        monitor="val_loss",
        save_last=False,
        filename=f"{args.filter_method}" + "-{epoch:02d}-{step}",
    )

    learning_rate_callback = pl.callbacks.LearningRateMonitor(logging_interval="step")

    # init the trainer and model
    trainer = pl.Trainer.from_argparse_args(
        args,
        callbacks=[
            checkpoint_callback,
            learning_rate_callback,
            LogZPKCallback(),
            LogTransferFnPlots(),
        ],
    )

    pl.seed_everything(args.seed)

    # setup the dataloaders
    train_datasetA = IIRFilterDataset(
        method="normal_poly",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_train_examples,
        precompute=args.precompute,
    )

    train_datasetB = IIRFilterDataset(
        method="normal_biquad",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_train_examples,
        precompute=args.precompute,
    )

    train_datasetC = IIRFilterDataset(
        method="uniform_disk",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_train_examples,
        precompute=args.precompute,
    )

    train_datasetD = IIRFilterDataset(
        method="uniform_mag_disk",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_train_examples,
        precompute=args.precompute,
    )

    train_datasetE = IIRFilterDataset(
        method="char_poly",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_train_examples,
        precompute=args.precompute,
    )

    train_datasetF = IIRFilterDataset(
        method="uniform_parametric",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_train_examples,
        precompute=args.precompute,
    )

    filter_datasets = {
        "normal_poly": train_datasetA,
        "normal_biquad": train_datasetB,
        "uniform_disk": train_datasetC,
        "uniform_mag_disk": train_datasetD,
        "char_poly": train_datasetE,
        "uniform_parametric": train_datasetF,
        "all": torch.utils.data.ConcatDataset(
            [
                train_datasetA,
                train_datasetB,
                train_datasetC,
                train_datasetD,
                train_datasetE,
                train_datasetF,
            ]
        ),
    }

    train_dataset = filter_datasets[args.filter_method]

    train_dataloader = torch.utils.data.DataLoader(
        train_dataset,
        shuffle=args.shuffle,
        batch_size=args.batch_size,
        num_workers=args.num_workers,
        worker_init_fn=wif,
        pin_memory=True,
    )

    val_datasetA = IIRFilterDataset(
        method="normal_poly",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_val_examples,
        precompute=args.precompute,
    )

    val_datasetB = IIRFilterDataset(
        method="normal_biquad",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_val_examples,
        precompute=args.precompute,
    )

    val_datasetC = IIRFilterDataset(
        method="uniform_disk",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_val_examples,
        precompute=args.precompute,
    )

    val_datasetD = IIRFilterDataset(
        method="uniform_mag_disk",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_val_examples,
        precompute=args.precompute,
    )

    val_datasetE = IIRFilterDataset(
        method="char_poly",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_val_examples,
        precompute=args.precompute,
    )

    val_datasetF = IIRFilterDataset(
        method="uniform_parametric",
        num_points=args.num_points,
        max_order=args.max_train_order,
        num_examples=args.num_val_examples,
        precompute=args.precompute,
    )

    filter_val_datasets = {
        "normal_poly": val_datasetA,
        "normal_biquad": val_datasetB,
        "uniform_disk": val_datasetC,
        "uniform_mag_disk": val_datasetD,
        "char_poly": val_datasetE,
        "uniform_parametric": val_datasetF,
        "all": torch.utils.data.ConcatDataset(
            [
                val_datasetA,
                val_datasetB,
                val_datasetC,
                val_datasetD,
                val_datasetE,
                val_datasetF,
            ]
        ),
    }

    val_dataloader = torch.utils.data.DataLoader(
        filter_val_datasets[args.filter_method],
        shuffle=args.shuffle,
        batch_size=args.batch_size,
        num_workers=args.num_workers,
        worker_init_fn=wif,
        pin_memory=False,
    )

    # build the model
    if args.model_name == "mlp":
        model = MLPModel(**vars(args))
    elif args.model_name == "lstm":
        model = LSTMModel(**vars(args))

    # train!
    trainer.fit(model, train_dataloader, val_dataloader)
